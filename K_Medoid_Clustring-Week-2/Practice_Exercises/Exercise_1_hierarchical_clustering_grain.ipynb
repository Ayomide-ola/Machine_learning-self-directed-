# %% [markdown]
# # Exercise 1
# ## Hierarchical clustering of the grain data
#
# Use the `linkage()` function to obtain a hierarchical clustering of the grain samples, and use `dendrogram()` to visualize the result.  A sample of the grain measurements is provided in the array `samples`, while the variety of each grain sample is given by the list `varieties`.

# %% [markdown]
# **Step 1:** Load the dataset.

# %%
import pandas as pd

seeds_df = pd.read_csv('seeds-less-rows.csv')

# remove the grain species from the DataFrame, save for later
varieties = list(seeds_df.pop('grain_variety'))

# extract the measurements as a NumPy array
samples = seeds_df.values

# %% [markdown]
# **Step 2:** Import:
#
#  + `linkage` and `dendrogram` from `scipy.cluster.hierarchy`.
#  + `matplotlib.pyplot` as `plt`.

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
import matplotlib.pyplot as plt

# %%
print(samples)
# Out:
# [[14.88   14.57    0.8811  5.554   3.333   1.018   4.956 ]
#  [14.69   14.49    0.8799  5.563   3.259   3.586   5.219 ]
#  [14.03   14.16    0.8796  5.438   3.201   1.717   5.001 ]
#  [13.99   13.83    0.9183  5.119   3.383   5.234   4.781 ]
#  [14.11   14.26    0.8722  5.52    3.168   2.688   5.219 ]
#  [13.02   13.76    0.8641  5.395   3.026   3.373   4.825 ]
#  [15.49   14.94    0.8724  5.757   3.371   3.412   5.228 ]
#  [16.2    15.27    0.8734  5.826   3.464   2.823   5.527 ]
#  [13.5    13.85    0.8852  5.351   3.158   2.249   5.176 ]
#  [15.36   14.76    0.8861  5.701   3.393   1.367   5.132 ]
#  [15.78   14.91    0.8923  5.674   3.434   5.593   5.136 ]
#  [14.46   14.35    0.8818  5.388   3.377   2.802   5.044 ]
#  [11.23   12.63    0.884   4.902   2.879   2.269   4.703 ]
#  [14.34   14.37    0.8726  5.63    3.19    1.313   5.15  ]
#  [16.84   15.67    0.8623  5.998   3.484   4.675   5.877 ]
#  [17.32   15.91    0.8599  6.064   3.403   3.824   5.922 ]
# ...

# %%
import pandas as pd 
df= pd.DataFrame(data=varieties)

# %%
df[0].unique()
# Out:
# array(['Kama wheat', 'Rosa wheat', 'Canadian wheat'], dtype=object)

# %%
X = samples[:, ]

# %%
X
# Out:
# array([[14.88  , 14.57  ,  0.8811,  5.554 ,  3.333 ,  1.018 ,  4.956 ],
#        [14.69  , 14.49  ,  0.8799,  5.563 ,  3.259 ,  3.586 ,  5.219 ],
#        [14.03  , 14.16  ,  0.8796,  5.438 ,  3.201 ,  1.717 ,  5.001 ],
#        [13.99  , 13.83  ,  0.9183,  5.119 ,  3.383 ,  5.234 ,  4.781 ],
#        [14.11  , 14.26  ,  0.8722,  5.52  ,  3.168 ,  2.688 ,  5.219 ],
#        [13.02  , 13.76  ,  0.8641,  5.395 ,  3.026 ,  3.373 ,  4.825 ],
#        [15.49  , 14.94  ,  0.8724,  5.757 ,  3.371 ,  3.412 ,  5.228 ],
#        [16.2   , 15.27  ,  0.8734,  5.826 ,  3.464 ,  2.823 ,  5.527 ],
#        [13.5   , 13.85  ,  0.8852,  5.351 ,  3.158 ,  2.249 ,  5.176 ],
#        [15.36  , 14.76  ,  0.8861,  5.701 ,  3.393 ,  1.367 ,  5.132 ],
#        [15.78  , 14.91  ,  0.8923,  5.674 ,  3.434 ,  5.593 ,  5.136 ],
#        [14.46  , 14.35  ,  0.8818,  5.388 ,  3.377 ,  2.802 ,  5.044 ],
#        [11.23  , 12.63  ,  0.884 ,  4.902 ,  2.879 ,  2.269 ,  4.703 ],
# ...

# %% [markdown]
# **Step 3:** Perform hierarchical clustering on `samples` using the `linkage()` function with the `method='complete'` keyword argument. Assign the result to `mergings`.

# %%
# import the library for hierarchical clustering
import scipy.cluster.hierarchy as sch

# Call the method dendrogram by using an object sch
mergings = sch.dendrogram(sch.linkage(samples, method = 'complete')) # Single joins from the smallest 
plt.title('Mergins')
plt.xlabel('Samples')
plt.ylabel('Èuclidean Distance')
plt.show()

# %% [markdown]
# **Step 4:** Plot a dendrogram using the `dendrogram()` function on `mergings`, specifying the keyword arguments `labels=varieties`, `leaf_rotation=90`, and `leaf_font_size=6`.  Remember to call `plt.show()` afterwards, to display your plot.

# %%
seeds_df.head()
# Out:
#     area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0  14.88      14.57       0.8811   5.554  3.333                  1.018
# 1  14.69      14.49       0.8799   5.563  3.259                  3.586
# 2  14.03      14.16       0.8796   5.438  3.201                  1.717
# 3  13.99      13.83       0.9183   5.119  3.383                  5.234
# 4  14.11      14.26       0.8722   5.520  3.168                  2.688
#
#    groove_length
# 0          4.956
# 1          5.219
# 2          5.001
# 3          4.781
# 4          5.219

# %%
X= seeds_df.iloc[:, [2,3]].values

# %%
# import the library for Agglomerative clustering
from sklearn.cluster import AgglomerativeClustering

# Initialise an object 'hc' by calling a method 'AgglomerativeClustering'
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')

# Train the model by calling a method 'fit_predict(X)'
y_hc = hc.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 50, c = 'red', label = 'Kama wheat')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 50, c = 'blue', label = 'Rosa wheat')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 50, c = 'green', label = 'Canadian wheat')
#plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 50, c = 'cyan', label = 'Careless')
#plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 50, c = 'magenta', label = 'Sensible')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# C:\Users\timay\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
X_1= seeds_df.iloc[:, [3,4]].values

# %%
X_1
# Out:
# array([[5.554, 3.333],
#        [5.563, 3.259],
#        [5.438, 3.201],
#        [5.119, 3.383],
#        [5.52 , 3.168],
#        [5.395, 3.026],
#        [5.757, 3.371],
#        [5.826, 3.464],
#        [5.351, 3.158],
#        [5.701, 3.393],
#        [5.674, 3.434],
#        [5.388, 3.377],
#        [4.902, 2.879],
#        [5.63 , 3.19 ],
#        [5.998, 3.484],
#        [6.064, 3.403],
#        [6.006, 3.857],
#        [6.084, 3.764],
#        [6.172, 3.796],
#        [6.341, 3.81 ],
#        [5.89 , 3.694],
#        [6.152, 3.806],
#        [6.303, 3.791],
#        [6.051, 3.897],
#        [6.059, 3.563],
#        [6.285, 3.594],
#        [6.144, 3.825],
#        [6.145, 3.574],
#        [5.541, 3.073],
#        [5.176, 2.719],
#        [5.405, 2.776],
#        [5.053, 2.849],
#        [5.35 , 2.81 ],
#        [5.319, 2.897],
#        [5.167, 2.845],
#        [5.186, 2.71 ],
#        [5.236, 3.017],
#        [5.413, 2.716],
#        [5.091, 2.804],
#        [5.224, 3.054],
# ...

# %%
# import the library for Agglomerative clustering
from sklearn.cluster import AgglomerativeClustering

# Initialise an object 'hc' by calling a method 'AgglomerativeClustering'
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')

# Train the model by calling a method 'fit_predict(X)'
y_hc = hc.fit_predict(X)

# Visualising the clusters
plt.scatter(X_1[y_hc == 0, 0], X_1[y_hc == 0, 1], s = 50, c = 'red', label = 'Kama wheat')
plt.scatter(X_1[y_hc == 1, 0], X_1[y_hc == 1, 1], s = 50, c = 'blue', label = 'Rosa wheat')
plt.scatter(X_1[y_hc == 2, 0], X_1[y_hc == 2, 1], s = 50, c = 'green', label = 'Canadian wheat')
#plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 50, c = 'cyan', label = 'Careless')
#plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 50, c = 'magenta', label = 'Sensible')
plt.title('Clusters of customers')
plt.xlabel('compactness')
plt.ylabel('length')
plt.legend()
plt.show()
# Out:
# C:\Users\timay\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %% [markdown]
# # CONT
# 1. Explain the visualisation..
# 2. Try with of variable compaison

# %% [markdown]
# ## Reference:
# * <p>https://www.udemy.com/transition-to-data-science-in-python/?couponCode=HIERARCH-NBS</p>
